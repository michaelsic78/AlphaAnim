# %%
from alpha import *
png = 'Images/snowman.png'
audio,sr = run_alpha(png,fps=10,triangle_sound='brass',edge_sound='wood',birth_sound='plucked string',death_sound='bell')
ipd.Audio(audio,rate=sr)
# Out:
# 100
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print_user_guide()
# Out:
# Welcome to the Alpha Animation with Sound python program!
#
# The current supported sounds are the following
# ----------------------------------------------
# karplus
# plucked string
# bell
# brass
# drum
# dirty bass
# wood
#
# You can add sound to the following events: the addition of an edge, the creation of a triangle, and the birth and death of topological events
# You should also specificy what you FPS you intend to make the final animation so the audio lines up. The default is 30 frames per second.
# Start the program by calling the run_alpha() method. Make sure to specificy the png of your point cloud. You can add sounds through this method as well
#
# See an example run below
# ------------------------
# run_alpha(png="snowman.png",fps=30,triangle_sound="brass",edge_sound="dirty bass",birth_sound="wood",death_sound="bell")
#
# You can also specify the number of frames in the final product with the scales argument
# ...
